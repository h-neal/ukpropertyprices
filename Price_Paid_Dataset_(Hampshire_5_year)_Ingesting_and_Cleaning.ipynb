# %% [markdown]
# <a href="https://colab.research.google.com/github/h-neal/ukpropertyprices/blob/main/Price_Paid_Dataset_(Hampshire_5_year)_Ingesting_and_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. INGESTING HOUSING DATASET**

# %%
# Scraping the 2019 data from Price Paid .GOV website: http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2019.txt

import pandas as pd
url = 'http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2019.txt'
housing_data_2019 = pd.read_csv(url)

# %%
# Adding the appropriate column labels to the 2019 dataset:

housing_data_2019.columns = [
    "Transaction Unique ID",
    "Price",
    "Date of Transfer",
    "Post Code",
    "Property Type",
    "New Build? (Y/N)",
    "Duration",
    "Primary Addressable Object Name (PAON)",
    "Secondary Addressable Object Name (SAON)",
    "Street Name",
    "Locality",
    "Town/City",
    "District",
    "County",
    "PPD Category Type",                            # indicates the type of Price Paid transaction
                                                    # A = Standard Price Paid entry, includes single residential property sold for full market value
                                                    # B = Additional Price Paid entry including transfers under a power of sale/repossessions, buy-to-lets (where they can be identified by a Mortgage) and transfers to non-private individuals.

    "Record Status"                                 # indicates additions, changes and deletions to the records.
                                                    # A = Addition
                                                    # C = Change
                                                    # D = Delete
    ]

# %%
# Scraping the 2020 data from Price Paid .GOV website: http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2020.txt

url = 'http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2020.txt'
housing_data_2020 = pd.read_csv(url)

# %%
# Adding the appropriate column labels to the 2020 dataset:

housing_data_2020.columns = [
    "Transaction Unique ID",
    "Price",
    "Date of Transfer",
    "Post Code",
    "Property Type",
    "New Build? (Y/N)",
    "Duration",
    "Primary Addressable Object Name (PAON)",
    "Secondary Addressable Object Name (SAON)",
    "Street Name",
    "Locality",
    "Town/City",
    "District",
    "County",
    "PPD Category Type",                            # indicates the type of Price Paid transaction
                                                    # A = Standard Price Paid entry, includes single residential property sold for full market value
                                                    # B = Additional Price Paid entry including transfers under a power of sale/repossessions, buy-to-lets (where they can be identified by a Mortgage) and transfers to non-private individuals.

    "Record Status"                                 # indicates additions, changes and deletions to the records.
                                                    # A = Addition
                                                    # C = Change
                                                    # D = Delete
    ]

# %%
# Scraping the 2021 data from Price Paid .GOV website: http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2021.txt

url = 'http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2021.txt'
housing_data_2021 = pd.read_csv(url)

# %%
# Adding the appropriate column labels to the 2021 dataset:

housing_data_2021.columns = [
    "Transaction Unique ID",
    "Price",
    "Date of Transfer",
    "Post Code",
    "Property Type",
    "New Build? (Y/N)",
    "Duration",
    "Primary Addressable Object Name (PAON)",
    "Secondary Addressable Object Name (SAON)",
    "Street Name",
    "Locality",
    "Town/City",
    "District",
    "County",
    "PPD Category Type",                            # indicates the type of Price Paid transaction
                                                    # A = Standard Price Paid entry, includes single residential property sold for full market value
                                                    # B = Additional Price Paid entry including transfers under a power of sale/repossessions, buy-to-lets (where they can be identified by a Mortgage) and transfers to non-private individuals.

    "Record Status"                                 # indicates additions, changes and deletions to the records.
                                                    # A = Addition
                                                    # C = Change
                                                    # D = Delete
    ]

# %%
# Scraping the 2022 data from Price Paid .GOV website: http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2022.txt

url = 'http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2022.txt'
housing_data_2022 = pd.read_csv(url)

# %%
# Adding the appropriate column labels to the 2022 dataset:

housing_data_2022.columns = [
    "Transaction Unique ID",
    "Price",
    "Date of Transfer",
    "Post Code",
    "Property Type",
    "New Build? (Y/N)",
    "Duration",
    "Primary Addressable Object Name (PAON)",
    "Secondary Addressable Object Name (SAON)",
    "Street Name",
    "Locality",
    "Town/City",
    "District",
    "County",
    "PPD Category Type",                            # indicates the type of Price Paid transaction
                                                    # A = Standard Price Paid entry, includes single residential property sold for full market value
                                                    # B = Additional Price Paid entry including transfers under a power of sale/repossessions, buy-to-lets (where they can be identified by a Mortgage) and transfers to non-private individuals.

    "Record Status"                                 # indicates additions, changes and deletions to the records.
                                                    # A = Addition
                                                    # C = Change
                                                    # D = Delete
    ]

# %%
# Scraping the 2023 data from Price Paid .GOV website: http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2023.txt

url = 'http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2023.txt'
housing_data_2023 = pd.read_csv(url)

# %%
# Adding the appropriate column labels to the 2023 dataset:

housing_data_2023.columns = [
    "Transaction Unique ID",
    "Price",
    "Date of Transfer",
    "Post Code",
    "Property Type",
    "New Build? (Y/N)",
    "Duration",
    "Primary Addressable Object Name (PAON)",
    "Secondary Addressable Object Name (SAON)",
    "Street Name",
    "Locality",
    "Town/City",
    "District",
    "County",
    "PPD Category Type",                            # indicates the type of Price Paid transaction
                                                    # A = Standard Price Paid entry, includes single residential property sold for full market value
                                                    # B = Additional Price Paid entry including transfers under a power of sale/repossessions, buy-to-lets (where they can be identified by a Mortgage) and transfers to non-private individuals.

    "Record Status"                                 # indicates additions, changes and deletions to the records.
                                                    # A = Addition
                                                    # C = Change
                                                    # D = Delete
    ]

# %%
# Combining the datasets

# Concatenating the datasets into a single DataFrame
housing_data = pd.concat([housing_data_2019, housing_data_2020, housing_data_2021, housing_data_2022, housing_data_2023], ignore_index=True)

# %%
# Showing the first 3 lines of housing_data

housing_data.head(3)
# Out:
#                     Transaction Unique ID   Price  Date of Transfer Post Code  \
# 0  {8CAC1318-5AA7-0253-E053-6B04A8C08E51}  116000  2019-06-07 00:00    L9 1DZ
# 1  {8CAC1318-5AA8-0253-E053-6B04A8C08E51}   60000  2019-05-23 00:00    L4 0RS
# 2  {8CAC1318-5AAA-0253-E053-6B04A8C08E51}  192000  2019-05-24 00:00   WA3 1EP
#
#   Property Type New Build? (Y/N) Duration  \
# 0             T                N        F
# 1             T                N        F
# 2             D                N        L
#
#   Primary Addressable Object Name (PAON)  \
# 0                                     91
# 1                                     26
# 2                                     23
#
#   Secondary Addressable Object Name (SAON)     Street Name Locality  \
# 0                                      NaN     BREEZE HILL      NaN
# 1                                      NaN  CONINGSBY ROAD      NaN
# 2                                      NaN      ABBEY ROAD   LOWTON
#
#     Town/City   District              County PPD Category Type Record Status
# 0   LIVERPOOL  LIVERPOOL          MERSEYSIDE                 A             A
# 1   LIVERPOOL  LIVERPOOL          MERSEYSIDE                 A             A
# 2  WARRINGTON      WIGAN  GREATER MANCHESTER                 A             A

# %%
# Filtering dataset for entries that occurred between January 2019 to December 2023

# Convert 'Date of Transfer' to datetime objects
housing_data['Date of Transfer'] = pd.to_datetime(housing_data['Date of Transfer'])

# Filter the dataset for entries between January 2019 and December 2023
filtered_housing_data = housing_data[(housing_data['Date of Transfer'] >= '2019-01-01') & (housing_data['Date of Transfer'] <= '2023-12-31')]

# Display the first few rows of the filtered dataset
filtered_housing_data.head()
# Out:
#                     Transaction Unique ID   Price Date of Transfer Post Code  \
# 0  {8CAC1318-5AA7-0253-E053-6B04A8C08E51}  116000       2019-06-07    L9 1DZ
# 1  {8CAC1318-5AA8-0253-E053-6B04A8C08E51}   60000       2019-05-23    L4 0RS
# 2  {8CAC1318-5AAA-0253-E053-6B04A8C08E51}  192000       2019-05-24   WA3 1EP
# 3  {8CAC1318-5AAB-0253-E053-6B04A8C08E51}  166000       2019-06-07   PR1 0YA
# 4  {8CAC1318-5AAC-0253-E053-6B04A8C08E51}  135000       2019-05-03    L7 8RU
#
#   Property Type New Build? (Y/N) Duration  \
# 0             T                N        F
# 1             T                N        F
# 2             D                N        L
# 3             S                N        F
# 4             T                N        F
#
#   Primary Addressable Object Name (PAON)  \
# 0                                     91
# 1                                     26
# 2                                     23
# 3                                      4
# 4                                     89
#
#   Secondary Addressable Object Name (SAON)     Street Name    Locality  \
# 0                                      NaN     BREEZE HILL         NaN
# 1                                      NaN  CONINGSBY ROAD         NaN
# 2                                      NaN      ABBEY ROAD      LOWTON
# 3                                      NaN       LARCHWOOD  PENWORTHAM
# 4                                      NaN     SAXONY ROAD         NaN
#
#     Town/City      District              County PPD Category Type  \
# 0   LIVERPOOL     LIVERPOOL          MERSEYSIDE                 A
# 1   LIVERPOOL     LIVERPOOL          MERSEYSIDE                 A
# 2  WARRINGTON         WIGAN  GREATER MANCHESTER                 A
# 3     PRESTON  SOUTH RIBBLE          LANCASHIRE                 A
# 4   LIVERPOOL     LIVERPOOL          MERSEYSIDE                 B
#
#   Record Status
# 0             A
# 1             A
# 2             A
# 3             A
# 4             A

# %%
# Filtering the dataset for entries where the value of the column labelled 'County' is "HAMPSHIRE"

housing_data = filtered_housing_data[filtered_housing_data['County'] == 'HAMPSHIRE']

# %% [markdown]
# **2. CLEANING AND PREPARING HOUSING DATASET FOR DATA EXPLORATION**

# %% [markdown]
# 2.1. Understanding the dataset

# %%
# Counting the number of entries in the dataset

housing_data.shape[0]
# Out:
# 124905

# %%
# Producing a table that lists the data type type of each column

housing_data.dtypes
# Out:
# Transaction Unique ID                               object
# Price                                                int64
# Date of Transfer                            datetime64[ns]
# Post Code                                           object
# Property Type                                       object
# New Build? (Y/N)                                    object
# Duration                                            object
# Primary Addressable Object Name (PAON)              object
# Secondary Addressable Object Name (SAON)            object
# Street Name                                         object
# Locality                                            object
# Town/City                                           object
# District                                            object
# County                                              object
# PPD Category Type                                   object
# Record Status                                       object
# dtype: object

# %%
# Producing a table which lists the number of distinct values for each column

housing_data.nunique()
# Out:
# Transaction Unique ID                       124905
# Price                                         6924
# Date of Transfer                              1463
# Post Code                                    27518
# Property Type                                    5
# New Build? (Y/N)                                 2
# Duration                                         2
# Primary Addressable Object Name (PAON)       12789
# Secondary Addressable Object Name (SAON)      1386
# Street Name                                  14160
# Locality                                       606
# Town/City                                       48
# District                                        11
# County                                           1
# PPD Category Type                                2
# Record Status                                    1
# dtype: int64

# %% [markdown]
# 2.2. Removing Duplicates

# %%
# Confirming that the number of entries in the dataset is the same as the number of unique values for the column "Transaction Unique ID".

if housing_data.shape[0] == housing_data['Transaction Unique ID'].nunique():
  print("There are no duplicate transaction IDs in the dataset.")
else:
  print("There are duplicate transaction IDs in the dataset.")
# Out:
# There are no duplicate transaction IDs in the dataset.

# %%
# Producing a table which lists the number of missing values in each column.

housing_data.isna().sum()
# Out:
# Transaction Unique ID                            0
# Price                                            0
# Date of Transfer                                 0
# Post Code                                      452
# Property Type                                    0
# New Build? (Y/N)                                 0
# Duration                                         0
# Primary Addressable Object Name (PAON)           0
# Secondary Addressable Object Name (SAON)    110127
# Street Name                                   1810
# Locality                                     68139
# Town/City                                        0
# District                                         0
# County                                           0
# PPD Category Type                                0
# Record Status                                    0
# dtype: int64

# %%
# Concatanating the columns "Post Code", "Primary Addressable Object Name (PAON)" and "Secondary Addressable Object Name (SAON)"

housing_data['Full Address'] = housing_data['Post Code'].astype(str) + " " + housing_data['Primary Addressable Object Name (PAON)'].astype(str) + " " + housing_data['Secondary Addressable Object Name (SAON)'].astype(str)
# Out:
# <ipython-input-215-815b02cd286c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_data['Full Address'] = housing_data['Post Code'].astype(str) + " " + housing_data['Primary Addressable Object Name (PAON)'].astype(str) + " " + housing_data['Secondary Addressable Object Name (SAON)'].astype(str)

# %%
# Concatanating the columns "Street Name", "Primary Addressable Object Name (PAON)" and "Secondary Addressable Object Name (SAON)"

housing_data['Full Address 2'] = housing_data['Street Name'].astype(str) + " " + housing_data['Primary Addressable Object Name (PAON)'].astype(str) + " " + housing_data['Secondary Addressable Object Name (SAON)'].astype(str)
# Out:
# <ipython-input-216-79f169322875>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   housing_data['Full Address 2'] = housing_data['Street Name'].astype(str) + " " + housing_data['Primary Addressable Object Name (PAON)'].astype(str) + " " + housing_data['Secondary Addressable Object Name (SAON)'].astype(str)

# %%
# Producing a table where the counts of the values of the "Full Address" or "Full Address 2" is greater than 1

# Finding the counts of the values of the "Full Address" or "Full Address 2"
address_counts = housing_data['Full Address'].value_counts()
address_counts_2 = housing_data['Full Address 2'].value_counts()

# Filtering the counts to show only those greater than 1
duplicate_addresses = address_counts[address_counts > 1]
duplicate_addresses_2 = address_counts_2[address_counts_2 > 1]

# Displaying the results
print("Duplicate Addresses (Full Address):")
print(duplicate_addresses)

print("\nDuplicate Addresses (Full Address 2):")
print(duplicate_addresses_2)
# Out:
# Duplicate Addresses (Full Address):
# Full Address
# SP6 1DJ 23 nan                     5
# nan GARAGE nan                     5
# SO22 5HD WEST BEECH CORNER, 6 1    4
# nan GARAGES 1-6 nan                4
# SO23 0JZ 113 nan                   4
#                                   ..
# GU34 5PP HOLLYBANK nan             2
# SO43 7AL 20 nan                    2
# SO51 0AP 14 nan                    2
# PO7 6PJ 43 nan                     2
# PO15 6AW 6 nan                     2
# Name: count, Length: 8435, dtype: int64
#
# Duplicate Addresses (Full Address 2):
# Full Address 2
# nan ROSE COTTAGE nan                         15
# NEW ROAD 4 nan                                7
# nan YEW TREE COTTAGE nan                      7
# PARK ROAD 3 nan                               7
# HIGH STREET 31 nan                            6
#                                              ..
# WITHERS ROAD 4 nan                            2
# UPPER CRABBICK LANE WILLOW TREE HOUSE nan     2
# PRINCE OF WALES ROAD 13 nan                   2
# MOONSCROSS AVENUE 10 nan                      2
# ROMSEY ROAD 11 nan                            2
# Name: count, Length: 10519, dtype: int64

# %%
# Producing a count of the entries in the tables above

print(len(duplicate_addresses))
print(len(duplicate_addresses_2))
# Out:
# 8435
# 10519

# %%
# Removing all entries in duplicate_addresses_1 or duplicate_addresses_2 from the dataset

# Create a boolean mask for rows with duplicate addresses
duplicate_mask = housing_data['Full Address'].isin(duplicate_addresses.index) | housing_data['Full Address 2'].isin(duplicate_addresses_2.index)

# Remove rows with duplicate addresses
housing_data = housing_data[~duplicate_mask]

# %%
# Counting the number of entries in the dataset

housing_data.shape[0]
# Out:
# 102484

# %%
# Counting the number of entries where the value of the column "Record Status" is "C" or "D"

count_C_D = housing_data[housing_data["Record Status"].isin(["C", "D"])].shape[0]
print(count_C_D)
# Out:
# 0

# %%
# Removing all entries where the value of the column "Record Status" is "C" or "D"

housing_data = housing_data[~housing_data["Record Status"].isin(["C", "D"])]

# %%
# Counting the number of entries in the dataset

housing_data.shape[0]
# Out:
# 102484

# %% [markdown]
# 2.3. Handling Missing Values

# %%
# Producing a table which lists the number of missing values in each column.

housing_data.isna().sum()
# Out:
# Transaction Unique ID                           0
# Price                                           0
# Date of Transfer                                0
# Post Code                                     343
# Property Type                                   0
# New Build? (Y/N)                                0
# Duration                                        0
# Primary Addressable Object Name (PAON)          0
# Secondary Addressable Object Name (SAON)    90154
# Street Name                                  1412
# Locality                                    55762
# Town/City                                       0
# District                                        0
# County                                          0
# PPD Category Type                               0
# Record Status                                   0
# Full Address                                    0
# Full Address 2                                  0
# dtype: int64

# %%
# Producing a table which lists the percentage of missing data in each column.

housing_data.isna().sum() * 100 / len(housing_data)
# Out:
# Transaction Unique ID                        0.000000
# Price                                        0.000000
# Date of Transfer                             0.000000
# Post Code                                    0.334686
# Property Type                                0.000000
# New Build? (Y/N)                             0.000000
# Duration                                     0.000000
# Primary Addressable Object Name (PAON)       0.000000
# Secondary Addressable Object Name (SAON)    87.968854
# Street Name                                  1.377776
# Locality                                    54.410445
# Town/City                                    0.000000
# District                                     0.000000
# County                                       0.000000
# PPD Category Type                            0.000000
# Record Status                                0.000000
# Full Address                                 0.000000
# Full Address 2                               0.000000
# dtype: float64

# %%
# Producing a table which lists the number of entries for each Property Type where the Secondary Addressable Object Name (SAON) value is missing

housing_data[housing_data['Secondary Addressable Object Name (SAON)'].isna()]['Property Type'].value_counts()
# Out:
# Property Type
# D    32749
# S    23422
# T    22884
# F     7288
# O     3811
# Name: count, dtype: int64

# %%
# Retrieving the number of entries where the Post Code and the Street Name are missing values.

housing_data[(housing_data['Post Code'].isna()) & (housing_data['Street Name'].isna())].shape[0]
# Out:
# 74

# %%
# Removing the column "Record Status"

housing_data = housing_data.drop(columns=['Record Status'])

# %%
# Removing the column "Locality"

housing_data = housing_data.drop(columns=['Locality'])

# %%
# Removing the column "Street Name".

housing_data = housing_data.drop(columns=['Street Name'])

# %%
# Removing any entries where the Post Code is a missing value.

housing_data = housing_data.dropna(subset=['Post Code'])

# %%
# Producing a table which lists the number of missing values in each column to confirm that there are no missing values.

if housing_data.isna().sum().sum() == 0:
  print("There are no longer any missing values in the dataset.")
else:
  print("There are still missing values in the dataset.")
housing_data.isna().sum()
# Out:
# There are still missing values in the dataset.
# Transaction Unique ID                           0
# Price                                           0
# Date of Transfer                                0
# Post Code                                       0
# Property Type                                   0
# New Build? (Y/N)                                0
# Duration                                        0
# Primary Addressable Object Name (PAON)          0
# Secondary Addressable Object Name (SAON)    89919
# Town/City                                       0
# District                                        0
# County                                          0
# PPD Category Type                               0
# Full Address                                    0
# Full Address 2                                  0
# dtype: int64

# %% [markdown]
# 2.4. Correct Data Types

# %%
# Converting the column labelled data type of "Date of Transfer" to datetime.

housing_data['Date of Transfer'] = pd.to_datetime(housing_data['Date of Transfer'])

# %%
# Converting the data type of the columns labelled "Property Type", "New Build? (Y/N)", "Duration", "PPD Category Type" and "Property Type" to categorical

housing_data['Property Type'] = pd.Categorical(housing_data['Property Type'])
housing_data['New Build? (Y/N)'] = pd.Categorical(housing_data['New Build? (Y/N)'])
housing_data['Duration'] = pd.Categorical(housing_data['Duration'])
housing_data['PPD Category Type'] = pd.Categorical(housing_data['PPD Category Type'])

# %%
# Converting the data type of the columns labelled "Post Code", "Town/City", "District" and "County" to categorical

housing_data['Post Code'] = pd.Categorical(housing_data['Post Code'])
housing_data['Town/City'] = pd.Categorical(housing_data['Town/City'])
housing_data['District'] = pd.Categorical(housing_data['District'])
housing_data['County'] = pd.Categorical(housing_data['County'])

# %%
# Converting the data type of the column labelled "Price" to integer

housing_data['Price'] = housing_data['Price'].astype(int)

# %%
# Producing a table which lists the data type of each column

housing_data.dtypes
# Out:
# Transaction Unique ID                               object
# Price                                                int64
# Date of Transfer                            datetime64[ns]
# Post Code                                         category
# Property Type                                     category
# New Build? (Y/N)                                  category
# Duration                                          category
# Primary Addressable Object Name (PAON)              object
# Secondary Addressable Object Name (SAON)            object
# Town/City                                         category
# District                                          category
# County                                            category
# PPD Category Type                                 category
# Full Address                                        object
# Full Address 2                                      object
# dtype: object

# %% [markdown]
# 2.5 Standardising Text Fields

# %%
# Reformatting the text in the columns "Town/City", "District", and "County" by converting all to lowercase text and removing leading/trailing spaces.

text_columns = ["Town/City", "District", "County"]
for col in text_columns:
  housing_data[col] = housing_data[col].str.lower().str.strip()

# %%
# Producing a table that lists the number of unique values in the columns "Town/City", "District", and "County"

housing_data[["Town/City", "District", "County"]].nunique()
# Out:
# Town/City    48
# District     11
# County        1
# dtype: int64

# %% [markdown]
# 2.6. Outliers

# %%
# Producing a table which lists the minimum, maximum, mean, median, mode and range of the column "Price".
price_stats = {
    'Minimum': housing_data['Price'].min(),
    'Maximum': housing_data['Price'].max(),
    'Mean': housing_data['Price'].mean(),
    'Median': housing_data['Price'].median(),
    'Mode': housing_data['Price'].mode()[0],
    'Range': housing_data['Price'].max() - housing_data['Price'].min()
}
print(price_stats)
# Out:
# {'Minimum': 100, 'Maximum': 93050000, 'Mean': 444708.0298508924, 'Median': 346950.0, 'Mode': 350000, 'Range': 93049900}

# %%
# Detecting the number of outliers in the column "Price" using the Interquartile range

import numpy as np

# Calculating the first and third quartiles (Q1 and Q3)
Q1 = housing_data['Price'].quantile(0.25)
Q3 = housing_data['Price'].quantile(0.75)

# Calculating the interquartile range (IQR)
IQR = Q3 - Q1

# Defining the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identifying outliers
outliers_iqr = housing_data[(housing_data['Price'] < lower_bound) | (housing_data['Price'] > upper_bound)]

# Counting the number of outliers
num_outliers_iqr = outliers_iqr.shape[0]

print("Number of outliers in 'Price':", num_outliers_iqr)
# Out:
# Number of outliers in 'Price': 6464

# %%
# Calculating the number of outliers below the lower bound

lower_bound_outliers = housing_data[housing_data['Price'] < lower_bound]
num_lower_bound_outliers = lower_bound_outliers.shape[0]

print("Number of outliers below the lower bound:", num_lower_bound_outliers)
# Out:
# Number of outliers below the lower bound: 0

# %%
print(lower_bound)
# Out:
# -97425.0

# %%
# Detecting the number of outliers in the column "Price" using the Z-score

# Calculating the mean and standard deviation of the 'Price' column
mean = housing_data['Price'].mean()
std_dev = housing_data['Price'].std()

# Calculating the Z-score for each price value
housing_data['Price_Zscore'] = (housing_data['Price'] - mean) / std_dev

# Defining a threshold for outliers (e.g., 3 standard deviations)
threshold = 3

# Identifying outliers based on Z-score
outliers_zscore = housing_data[(housing_data['Price_Zscore'] > threshold) | (housing_data['Price_Zscore'] < -threshold)]

# Counting the number of outliers
num_outliers_zscore = outliers_zscore.shape[0]

print("Number of outliers in 'Price' using Z-score:", num_outliers_zscore)
# Out:
# Number of outliers in 'Price' using Z-score: 462

# %%
# Printing the number of outliers in the column "Price" below the threshold Z-score of -3

# Calculating the number of outliers below the threshold Z-score of -3
below_threshold_outliers = housing_data[housing_data['Price_Zscore'] < -3]
num_below_threshold_outliers = below_threshold_outliers.shape[0]

print("Number of outliers below the threshold Z-score of -3:", num_below_threshold_outliers)
# Out:
# Number of outliers below the threshold Z-score of -3: 0

# %%
# Plotting a boxplot of the column "Price"

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.boxplot(housing_data['Price'])
plt.title('Boxplot of Price')
plt.ylabel('Price')
plt.show()

# %%
# Producing a table which provides the count of values for "Price" between different thresholds

# Create bins for the price ranges
bins = [0, 100, 1000, 10000, 100000, 1000000]

# Cut the 'Price' column into the bins
housing_data['Price_Range'] = pd.cut(housing_data['Price'], bins=bins, labels=['0-100', '100-1000', '1000-10000', '10000-100000', '100000-1000000'])

# Count the values in each price range
price_range_counts = housing_data['Price_Range'].value_counts().sort_index()

# Display the table
print(price_range_counts)
# Out:
# Price_Range
# 0-100                 3
# 100-1000             31
# 1000-10000          144
# 10000-100000       1585
# 100000-1000000    96321
# Name: count, dtype: int64

# %%
# Producing a table of entries where the column "Price" is between 0 and 10000

# Filter the DataFrame for prices between 0 and 10000
price_range_100_10000 = housing_data[(housing_data['Price'] >= 0) & (housing_data['Price'] <= 10000)]

# Display the filtered table
price_range_100_10000.head()
# Out:
#                          Transaction Unique ID  Price Date of Transfer  \
# 58393   {919FEC06-1E0C-9A90-E053-6C04A8C0A300}    100       2019-06-24
# 60356   {919FEC06-1E25-9A90-E053-6C04A8C0A300}    400       2019-02-08
# 200309  {98C75472-B28F-72E9-E053-6B04A8C042F0}   3184       2019-10-29
# 204319  {98C75472-B2DD-72E9-E053-6B04A8C042F0}   1500       2019-10-25
# 206287  {98C75472-B302-72E9-E053-6B04A8C042F0}   6000       2019-04-12
#
#        Post Code Property Type New Build? (Y/N) Duration  \
# 58393   SO51 8DG             O                N        L
# 60356   RG22 4JQ             O                N        F
# 200309  PO13 9DA             O                N        F
# 204319  PO13 9UB             O                N        L
# 206287  PO12 4BQ             O                N        L
#
#        Primary Addressable Object Name (PAON)  \
# 58393                                       8
# 60356                                      73
# 200309                                    122
# 204319                                     17
# 206287                                 UNIT 4
#
#        Secondary Addressable Object Name (SAON)          Town/City  \
# 58393                                       NaN             romsey
# 60356                                       NaN        basingstoke
# 200309                                      NaN  lee-on-the-solent
# 204319                                      NaN            gosport
# 206287                                      NaN            gosport
#
#                      District     County PPD Category Type  \
# 58393             test valley  hampshire                 B
# 60356   basingstoke and deane  hampshire                 B
# 200309                gosport  hampshire                 B
# 204319                gosport  hampshire                 B
# 206287                gosport  hampshire                 B
#
#                Full Address              Full Address 2  Price_Zscore  \
# 58393        SO51 8DG 8 nan        LATIMER STREET 8 nan     -0.558578
# 60356       RG22 4JQ 73 nan           HAYDN ROAD 73 nan     -0.558201
# 200309     PO13 9DA 122 nan         HIGH STREET 122 nan     -0.554703
# 204319      PO13 9UB 17 nan          ROWNER ROAD 17 nan     -0.556819
# 206287  PO12 4BQ UNIT 4 nan  DARTMOUTH COURT UNIT 4 nan     -0.551166
#
#        Price_Range
# 58393        0-100
# 60356     100-1000
# 200309  1000-10000
# 204319  1000-10000
# 206287  1000-10000

# %%
# Counting the number of entries which have a value of "O" in the column "Property Type" and a value of "B" in the column "PPD Category Type"

count_O_B = housing_data[(housing_data['Property Type'] == 'O') & (housing_data['PPD Category Type'] == 'B')].shape[0]
print(count_O_B)
# Out:
# 4338

# %%
# Counting the number of entries which have a value of "B" in the column "PPD Category Type"

count_B = housing_data[housing_data['PPD Category Type'] == 'B'].shape[0]
print(count_B)
# Out:
# 9128

# %%
# Producing a table which shows the count of all the values in the column "Property Type" which have a value of "B" in the column "PPD Category Type"

# Filter the DataFrame for entries with "PPD Category Type" equal to "B"
filtered_data = housing_data[housing_data['PPD Category Type'] == 'B']

# Count the values in the "Property Type" column for the filtered data
property_type_counts = filtered_data['Property Type'].value_counts()

# Display the table
print(property_type_counts)
# Out:
# Property Type
# O    4338
# F    1677
# T    1478
# S     859
# D     776
# Name: count, dtype: int64

# %%
# Removing any entries where the value in the column "PPD Category Type" is equal to "B"
# This refers to Additional Price Paid entry which include transfers under a power of sale/repossessions,
# buy-to-lets (where they can be identified by a Mortgage), transfers to non-private individuals and sales
# where the property type is classed as ‘Other’. Deemed unnecessary for analysis.

housing_data = housing_data[housing_data['PPD Category Type'] != 'B']

# %%
# Removing the column labelled "PPD Category Type"

housing_data = housing_data.drop(columns=['PPD Category Type'])

# %%
# Counting the number of entries in the dataset

housing_data.shape[0]
# Out:
# 93013

# %%
# Producing a table which provides the count of values for "Price" between different thresholds

# Create bins for the price ranges
bins = [0, 100, 1000, 10000, 100000, 1000000]

# Cut the 'Price' column into the bins
housing_data['Price_Range'] = pd.cut(housing_data['Price'], bins=bins, labels=['0-100', '100-1000', '1000-10000', '10000-100000', '100000-1000000'])

# Count the values in each price range
price_range_counts = housing_data['Price_Range'].value_counts().sort_index()

# Display the table
print(price_range_counts)
# Out:
# Price_Range
# 0-100                 0
# 100-1000              0
# 1000-10000            1
# 10000-100000       1024
# 100000-1000000    89211
# Name: count, dtype: int64

# %%
# Producing a table of entries where the column "Price" is between 0 and 10000

# Filter the DataFrame for prices between 0 and 100
price_range_0_10000 = housing_data[(housing_data['Price'] >= 0) & (housing_data['Price'] <= 10000)]

# Display the filtered table
price_range_0_10000.head(40)
# Out:
#                           Transaction Unique ID  Price Date of Transfer  \
# 2683270  {F87E72F8-FF47-176C-E053-6B04A8C0D2BE}   2160       2021-05-12
#
#         Post Code Property Type New Build? (Y/N) Duration  \
# 2683270  SP11 7NB             T                N        F
#
#         Primary Addressable Object Name (PAON)  \
# 2683270                                    109
#
#         Secondary Addressable Object Name (SAON) Town/City     District  \
# 2683270                                      NaN   andover  test valley
#
#             County      Full Address           Full Address 2  Price_Zscore  \
# 2683270  hampshire  SP11 7NB 109 nan  BURY HILL CLOSE 109 nan      -0.55599
#
#         Price_Range
# 2683270  1000-10000

# %%
# Detecting the number of outliers in the column "Price" using the Interquartile range for the new dataset

# Calculating the first and third quartiles (Q1 and Q3)
Q1 = housing_data['Price'].quantile(0.25)
Q3 = housing_data['Price'].quantile(0.75)

# Calculating the interquartile range (IQR)
IQR = Q3 - Q1

# Defining the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identifying outliers
outliers_iqr = housing_data[(housing_data['Price'] < lower_bound) | (housing_data['Price'] > upper_bound)]

# Counting the number of outliers
num_outliers_iqr = outliers_iqr.shape[0]

print("Number of outliers in 'Price':", num_outliers_iqr)
# Out:
# Number of outliers in 'Price': 5271

# %%
# Calculating the number of outliers below the lower bound in the new dataset

lower_bound_outliers = housing_data[housing_data['Price'] < lower_bound]
num_lower_bound_outliers = lower_bound_outliers.shape[0]

print("Number of outliers below the lower bound:", num_lower_bound_outliers)
# Out:
# Number of outliers below the lower bound: 0

# %%
# Plotting a boxplot of the column "Price" with lines to indicate the upper and lower bounds

plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.boxplot(housing_data['Price'])
plt.title('Boxplot of Price')
plt.ylabel('Price')
plt.axhline(y=lower_bound, color='r', linestyle='--', label='Lower Bound')
plt.axhline(y=upper_bound, color='r', linestyle='--', label='Upper Bound')
plt.legend()
plt.show()

# %%
# Detecting the number of outliers in the column "Price" using the Z-score for the new dataset

# Calculating the mean and standard deviation of the 'Price' column
mean = housing_data['Price'].mean()
std_dev = housing_data['Price'].std()

# Calculating the Z-score for each price value
housing_data['Price_Zscore'] = (housing_data['Price'] - mean) / std_dev

# Defining a threshold for outliers (e.g., 3 standard deviations)
threshold = 3

# Identifying outliers based on Z-score
outliers_zscore = housing_data[(housing_data['Price_Zscore'] > threshold) | (housing_data['Price_Zscore'] < -threshold)]

# Counting the number of outliers
num_outliers_zscore = outliers_zscore.shape[0]

print("Number of outliers in 'Price' using Z-score:", num_outliers_zscore)
# Out:
# Number of outliers in 'Price' using Z-score: 1404

# %%
# Printing the number of outliers in the column "Price" below the threshold Z-score of -3

# Calculating the number of outliers below the threshold Z-score of -3
below_threshold_outliers = housing_data[housing_data['Price_Zscore'] < -3]
num_below_threshold_outliers = below_threshold_outliers.shape[0]

print("Number of outliers below the threshold Z-score of -3:", num_below_threshold_outliers)
# Out:
# Number of outliers below the threshold Z-score of -3: 0

# %%
# Plotting a boxplot of the column "Price" with lines to indicate the threshold z-scores

plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.boxplot(housing_data['Price'])
plt.title('Boxplot of Price')
plt.ylabel('Price')
plt.axhline(y=mean + threshold * std_dev, color='r', linestyle='--', label='Upper Z-score Threshold')
plt.axhline(y=mean - threshold * std_dev, color='r', linestyle='--', label='Lower Z-score Threshold')
plt.legend()
plt.show()

# %%
# Creating a new column which segments the entries based on their price:
# Entries where price is below IQR upper bound: Regular
# Entries where price is above IQR upper bound but below z-score upper threshold: High-End
# Entries where price is above z-score upper threshold: Luxury

# Calculating IQR upper bound
Q1 = housing_data['Price'].quantile(0.25)
Q3 = housing_data['Price'].quantile(0.75)
IQR = Q3 - Q1
upper_bound_iqr = Q3 + 1.5 * IQR

# Calculating Z-score upper threshold
mean = housing_data['Price'].mean()
std_dev = housing_data['Price'].std()
threshold = 3
upper_bound_zscore = mean + threshold * std_dev

# Create the new column
def price_segment(price):
  if price <= upper_bound_iqr:
    return 'Regular'
  elif price <= upper_bound_zscore:
    return 'High-End'
  else:
    return 'Luxury'

housing_data['Price_Segment'] = housing_data['Price'].apply(price_segment)

# %%
# Plotting a boxplot of the column "Price" for each value in "Price Segment"

plt.figure(figsize=(10, 6))  # Adjust figure size if needed
housing_data.boxplot(column='Price', by='Price_Segment')
plt.title('Boxplot of Price by Price Segment')
plt.ylabel('Price')
plt.xlabel('Price Segment')
plt.show()

# %%
# Removing the entries where the value of the column "Price" is in the top 3

# Sorting the DataFrame by 'Price' in descending order
housing_data_sorted = housing_data.sort_values('Price', ascending=False)

# Getting the indices of the top 3 entries
top_3_indices = housing_data_sorted.index[:4]

# Removing the top 4 entries from the DataFrame
housing_data = housing_data.drop(top_3_indices)

# %%
# Plotting a boxplot of the column "Price" for each value in "Price Segment"

plt.figure(figsize=(10, 6))  # Adjust figure size if needed
housing_data.boxplot(column='Price', by='Price_Segment')
plt.title('Boxplot of Price by Price Segment')
plt.ylabel('Price')
plt.xlabel('Price Segment')
plt.show()

# %%
# Producing a table which counts the number of unique values for "Price Segment"

# Counting the number of entries in unique values for "Price Segment"
price_segment_counts = housing_data['Price_Segment'].value_counts()

# Displaying the table
print(price_segment_counts)
# Out:
# Price_Segment
# Regular     87742
# High-End     3867
# Luxury       1400
# Name: count, dtype: int64

# %% [markdown]
# 2.7 Transforming Features

# %%
#Importing the geospatial dataset from Google Drive

from google.colab import drive
drive.mount('/content/drive')

# Use pd.read_pickle() to read the pickle file
df_geospatial_data = pd.read_pickle('/content/drive/MyDrive/Housing Prices Project/Geospatial Data/clean_geospatial_data.pkl')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Merging the housing_data dataset on the column lablled "Post Code" with the df_geospatial_data dataset on the column "postcode"

housing_data = housing_data.merge(df_geospatial_data, left_on='Post Code', right_on='Post Code', how='left')

# %%
# Showing the first 5 entries in the merged dataset

housing_data.head()
# Out:
#                     Transaction Unique ID   Price Date of Transfer Post Code  \
# 0  {8CAC1318-444E-0253-E053-6B04A8C08E51}  415000       2019-06-04  BH23 8HZ
# 1  {8CAC1318-4454-0253-E053-6B04A8C08E51}  289995       2019-06-21  PO14 2QN
# 2  {8CAC1318-4456-0253-E053-6B04A8C08E51}  320000       2019-02-26  GU14 7EL
# 3  {8CAC1318-4457-0253-E053-6B04A8C08E51}  257000       2019-06-19  SO30 0PA
# 4  {8CAC1318-465F-0253-E053-6B04A8C08E51}   87000       2019-05-29  GU32 3EQ
#
#   Property Type New Build? (Y/N) Duration  \
# 0             T                N        F
# 1             D                N        F
# 2             T                N        F
# 3             S                N        F
# 4             F                N        L
#
#   Primary Addressable Object Name (PAON)  \
# 0                                      5
# 1                                     30
# 2                                     10
# 3                                    200
# 4                           LAVANT COURT
#
#   Secondary Addressable Object Name (SAON)     Town/City  ...     County  \
# 0                                      NaN  christchurch  ...  hampshire
# 1                                      NaN       fareham  ...  hampshire
# 2                                      NaN   farnborough  ...  hampshire
# 3                                      NaN   southampton  ...  hampshire
# 4                                  FLAT 35   petersfield  ...  hampshire
#
#                     Full Address                       Full Address 2  \
# 0                 BH23 8HZ 5 nan                   HALTON CLOSE 5 nan
# 1                PO14 2QN 30 nan                   HAROLD ROAD 30 nan
# 2                GU14 7EL 10 nan                  WILTON COURT 10 nan
# 3               SO30 0PA 200 nan              CRANBOURNE PARK 200 nan
# 4  GU32 3EQ LAVANT COURT FLAT 35  CHARLES STREET LAVANT COURT FLAT 35
#
#   Price_Zscore     Price_Range Price_Segment   latitude  longitude  \
# 0     0.003940  100000-1000000       Regular  50.781076  -1.734407
# 1    -0.420690  100000-1000000       Regular  50.822977  -1.207633
# 2    -0.318766  100000-1000000       Regular  51.289394  -0.740748
# 3    -0.532770  100000-1000000       Regular  50.903678  -1.300642
# 4    -1.110244    10000-100000       Regular  51.006594  -0.940584
#
#   Post Code Area      Region
# 0             BH  South West
# 1             PO  South East
# 2             GU  South East
# 3             SO  South East
# 4             GU  South East
#
# [5 rows x 21 columns]

# %%
# Counting the number of missing values in the columns "latitude" and "longitude"

missing_latitude = housing_data['latitude'].isna().sum()
missing_longitude = housing_data['longitude'].isna().sum()

print(f"Missing values in 'latitude': {missing_latitude}")
print(f"Missing values in 'longitude': {missing_longitude}")
# Out:
# Missing values in 'latitude': 90
# Missing values in 'longitude': 90

# %%
# Producing a table of the entries where the values in the columns lablled "longitude" and "latitude" are missing

# Filtering the DataFrame for missing values in 'longitude' and 'latitude'
missing_geo_data = housing_data[housing_data['longitude'].isna() | housing_data['latitude'].isna()]

# Display the filtered table
missing_geo_data.head(5)
# Out:
#                         Transaction Unique ID   Price Date of Transfer  \
# 29847  {DBA933F9-7512-669D-E053-6B04A8C0AD56}  210000       2020-06-26
# 41318  {1A0C5C63-56A4-7CBE-E063-4804A8C06C96}  246000       2021-05-28
# 51161  {F5E8B081-51CD-3A13-E053-6C04A8C060B7}  195000       2021-07-02
# 82940  {237B17FE-08D6-22AC-E063-4804A8C0EA3A}  270000       2023-08-10
# 82951  {1C3E72FE-33BD-F410-E063-4804A8C0DFA6}  535000       2023-10-27
#
#       Post Code Property Type New Build? (Y/N) Duration  \
# 29847  SO50 9XA             F                Y        L
# 41318  GU14 7TQ             F                Y        L
# 51161  BH25 6FF             F                N        L
# 82940  PO15 7RF             D                Y        F
# 82951  SO16 8NQ             D                Y        F
#
#       Primary Addressable Object Name (PAON)  \
# 29847                   MITCHELL HOUSE 40-60
# 41318                        GRAND VIEW, 296
# 51161                          PURI COURT, 3
# 82940                                      3
# 82951                                      8
#
#       Secondary Addressable Object Name (SAON)    Town/City  ...     County  \
# 29847                                   FLAT 8    eastleigh  ...  hampshire
# 41318                                 FLAT 100  farnborough  ...  hampshire
# 51161                                        1   new milton  ...  hampshire
# 82940                                      NaN      fareham  ...  hampshire
# 82951                                      NaN  southampton  ...  hampshire
#
#                                Full Address  \
# 29847  SO50 9XA MITCHELL HOUSE 40-60 FLAT 8
# 41318     GU14 7TQ GRAND VIEW, 296 FLAT 100
# 51161              BH25 6FF PURI COURT, 3 1
# 82940                        PO15 7RF 3 nan
# 82951                        SO16 8NQ 8 nan
#
#                                      Full Address 2 Price_Zscore  \
# 29847  SOUTHAMPTON ROAD MITCHELL HOUSE 40-60 FLAT 8    -0.692425
# 41318     FARNBOROUGH ROAD GRAND VIEW, 296 FLAT 100    -0.570136
# 51161                     GORE ROAD PURI COURT, 3 1    -0.743378
# 82940                           NUTHATCH ROAD 3 nan    -0.488611
# 82951                           PARKERS DRIVE 8 nan     0.411569
#
#           Price_Range Price_Segment latitude longitude Post Code Area Region
# 29847  100000-1000000       Regular      NaN       NaN            NaN    NaN
# 41318  100000-1000000       Regular      NaN       NaN            NaN    NaN
# 51161  100000-1000000       Regular      NaN       NaN            NaN    NaN
# 82940  100000-1000000       Regular      NaN       NaN            NaN    NaN
# 82951  100000-1000000       Regular      NaN       NaN            NaN    NaN
#
# [5 rows x 21 columns]

# %%
# Removing the entries where the values in the columns lablled "longitude" and "latitude" are missing

# Filter the DataFrame to remove rows with missing values in 'longitude' or 'latitude'
housing_data = housing_data.dropna(subset=['longitude', 'latitude'])

# %%
# Counting the number of entries in the dataset

housing_data.shape[0]
# Out:
# 92919

# %%
# Producing a count of the unique values of the column labelled "Region"

region_counts = housing_data['Region'].value_counts()
print(region_counts)
# Out:
# Region
# South East         84100
# South West          8818
# West Midlands          1
# Channel Islands        0
# East Midlands          0
# East of England        0
# Greater London         0
# Isle of Man            0
# North East             0
# North West             0
# Scotland               0
# Wales                  0
# Name: count, dtype: int64

# %%
# Producing a table of the entries where the value is "West Midlands" the column labelled "Region"

# Filtering the DataFrame for entries with "Region" equal to "West Midlands"
west_midlands_data = housing_data[housing_data['Region'] == 'West Midlands']

# Displaying the filtered table
west_midlands_data.head()
# Out:
#                         Transaction Unique ID   Price Date of Transfer  \
# 42980  {01EB45EF-CD57-40F3-E063-4704A8C05FDE}  178125       2021-10-29
#
#       Post Code Property Type New Build? (Y/N) Duration  \
# 42980   DY6 7NF             T                N        L
#
#       Primary Addressable Object Name (PAON)  \
# 42980                                     58
#
#       Secondary Addressable Object Name (SAON)     Town/City  ...     County  \
# 42980                                      NaN  kingswinford  ...  hampshire
#
#          Full Address          Full Address 2 Price_Zscore     Price_Range  \
# 42980  DY6 7NF 58 nan  HERRINGBONE WAY 58 nan    -0.800701  100000-1000000
#
#       Price_Segment   latitude  longitude Post Code Area         Region
# 42980       Regular  52.508441  -2.144148             DY  West Midlands
#
# [1 rows x 21 columns]

# %%
# Removing the entries where the value is "West Midlands" the column labelled "Region" from the Dataset

# Filtering the DataFrame to remove rows with "Region" equal to "West Midlands"
housing_data = housing_data[housing_data['Region'] != 'West Midlands']

# %%
# Producing a count of the unique values in the column labelled "Post Code Area"

# Counting the unique values in the "Post Code Area" column
postcode_area_counts = housing_data['Post Code Area'].value_counts()

# Printing the counts
print(postcode_area_counts)
# Out:
# Post Code Area
# SO    30134
# PO    21751
# GU    18415
# RG    13800
# SP     5510
# BH     3307
# SN        1
# Name: count, dtype: int64

# %%
# Producing a table of the entries where the value is "SN" in the column labelled "Post Code Area"

sn_entries = housing_data[housing_data['Post Code Area'] == 'SN']
sn_entries.head()
# Out:
#                         Transaction Unique ID   Price Date of Transfer  \
# 75460  {DE2D0CDF-B96C-51EE-E053-6C04A8C00671}  925000       2022-01-24
#
#       Post Code Property Type New Build? (Y/N) Duration  \
# 75460   SN8 3RJ             D                N        F
#
#       Primary Addressable Object Name (PAON)  \
# 75460                            MORRIS DEAN
#
#       Secondary Addressable Object Name (SAON)    Town/City  ...     County  \
# 75460                                      NaN  marlborough  ...  hampshire
#
#                   Full Address       Full Address 2 Price_Zscore  \
# 75460  SN8 3RJ MORRIS DEAN nan  nan MORRIS DEAN nan     1.736361
#
#           Price_Range Price_Segment   latitude  longitude Post Code Area  \
# 75460  100000-1000000      High-End  51.331478  -1.533009             SN
#
#            Region
# 75460  South West
#
# [1 rows x 21 columns]

# %%
# Removing entries where the value is "SN" in the column labelled "Post Code Area"

# Filtering the DataFrame to remove rows with "Post Code Area" equal to "SN"
housing_data = housing_data[housing_data['Post Code Area'] != 'SN']

# %% [markdown]
# 2.8 Validating Data Integrity

# %%
# Checking if any values in the "Price" column are not positive
negative_prices = housing_data[housing_data['Price'] <= 0]

# Print the number of negative or zero price values
print("Number of non-positive price values:", len(negative_prices))
# Out:
# Number of non-positive price values: 0

# %%
# Checking that the column labelled "Postcode" follows the correct UK format

import re

# Define a regular expression for UK postcode format
postcode_pattern = r"^[A-Z]{1,2}[0-9R][0-9A-Z]? [0-9][ABD-HJLNP-UW-Z]{2}$"

# Check if Postcode values match the pattern
valid_postcodes = housing_data['Post Code'].str.match(postcode_pattern, na=False)

# Find invalid postcodes
invalid_postcodes = housing_data[~valid_postcodes]['Post Code']

# Print the number of invalid postcodes
print("Number of invalid postcodes:", len(invalid_postcodes))

# Print the invalid postcodes (optional)
print("Invalid postcodes:\n", invalid_postcodes)
# Out:
# Number of invalid postcodes: 0
# Invalid postcodes:
#  Series([], Name: Post Code, dtype: object)

# %% [markdown]
# 2.9 Final Dataset Review

# %%
# Checking for missing values

# Producing a table which lists the number of missing values in each column to confirm that there are no missing values.

if housing_data.isna().sum().sum() == 0:
  print("There are no missing values in the dataset.")
else:
  print("There are still missing values in the dataset.")
housing_data.isna().sum()
# Out:
# There are still missing values in the dataset.
# Transaction Unique ID                           0
# Price                                           0
# Date of Transfer                                0
# Post Code                                       0
# Property Type                                   0
# New Build? (Y/N)                                0
# Duration                                        0
# Primary Addressable Object Name (PAON)          0
# Secondary Addressable Object Name (SAON)    82558
# Town/City                                       0
# District                                        0
# County                                          0
# Full Address                                    0
# Full Address 2                                  0
# Price_Zscore                                    0
# Price_Range                                  2771
# Price_Segment                                   0
# latitude                                        0
# longitude                                       0
# Post Code Area                                  0
# Region                                          0
# dtype: int64

# %%
# Removing the column labelled "Price Range"

housing_data = housing_data.drop(columns=['Price_Range'])

# %%
# Removing the column labelled "Price_Zscore"

housing_data = housing_data.drop(columns=['Price_Zscore'])

# %%
# Removing the column labelled "Full Address"

housing_data = housing_data.drop(columns=['Full Address'])

# %%
# Removing the column labelled "Full Address 2"

housing_data = housing_data.drop(columns=['Full Address 2'])

# %%
# Removing the column labelled "County"

housing_data = housing_data.drop(columns=['County'])

# %%
# Removing the column labelled "Region"

housing_data = housing_data.drop(columns=['Region'])

# %%
# Checking for missing values

# Producing a table which lists the number of missing values in each column to confirm that there are no missing values.

if housing_data.isna().sum().sum() == 0:
  print("There are no missing values in the dataset.")
else:
  print("There are still missing values in the dataset.")
housing_data.isna().sum()
# Out:
# There are still missing values in the dataset.
# Transaction Unique ID                           0
# Price                                           0
# Date of Transfer                                0
# Post Code                                       0
# Property Type                                   0
# New Build? (Y/N)                                0
# Duration                                        0
# Primary Addressable Object Name (PAON)          0
# Secondary Addressable Object Name (SAON)    82558
# Town/City                                       0
# District                                        0
# Price_Segment                                   0
# latitude                                        0
# longitude                                       0
# Post Code Area                                  0
# dtype: int64

# %%
# Producing a table which lists the data type of each column

housing_data.dtypes
# Out:
# Transaction Unique ID                               object
# Price                                                int64
# Date of Transfer                            datetime64[ns]
# Post Code                                           object
# Property Type                                     category
# New Build? (Y/N)                                  category
# Duration                                          category
# Primary Addressable Object Name (PAON)              object
# Secondary Addressable Object Name (SAON)            object
# Town/City                                           object
# District                                            object
# Price_Segment                                       object
# latitude                                            object
# longitude                                           object
# Post Code Area                                      object
# dtype: object

# %% [markdown]
# **3. CREATING A CLEANED DATASET**

# %%
# Exporting the dataset as a .csv file

housing_data.to_csv('/content/drive/MyDrive/Housing Prices Project/Hampshire 5 Year/cleaned_housing_data_Hampshire_5_year.csv', index=False)

# %%
# Exporting the dataset as a pickle file to the file directory /content/drive/MyDrive/Housing Prices Project/ Replacing any dataset with the same file name.

housing_data.to_pickle('/content/drive/MyDrive/Housing Prices Project/Hampshire 5 Year/cleaned_housing_data_Hampshire_5_year.pkl')
